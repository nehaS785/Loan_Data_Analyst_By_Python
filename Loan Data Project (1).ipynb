# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('C:/Users/Neha Madam/OneDrive/Desktop/ETLHIVE/PYTHON/PROJECT 2/Python_projects/Loan_data_analysis_project/Loan_dataset.csv')
df
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
df.shape
# Out:
# (100514, 19)

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 105653

# %%
df.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         1.000000e+05  80846.000000   8.084600e+04  100000.000000
# mean          1.176045e+07   1076.456089   1.378277e+06   18472.412336
# std           3.178394e+07   1475.403791   1.081360e+06   12174.992609
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.796520e+05    705.000000   8.488440e+05   10214.162500
# 50%           3.122460e+05    724.000000   1.174162e+06   16220.300000
# 75%           5.249420e+05    741.000000   1.650663e+06   24012.057500
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count            100000.000000                  46859.000000
# mean                 18.199141                     34.901321
# std                   7.015324                     21.997829
# min                   3.600000                      0.000000
# ...

# %%
df['Loan ID'].duplicated().sum()
# Out:
# 18514

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 1.What is the average current loan amount for each loan status?
Average_current_loan_amount=df.groupby('Loan Status')['Current Loan Amount'].mean()
plt.figure(figsize=(8,4))
sns.barplot(x= Average_current_loan_amount.index,y=Average_current_loan_amount.values)
plt.title('Average Current Loan Amount By Status')
plt.xticks(rotation=45)
plt.ylabel('Average Loan Amount')
# Out:
# Text(0, 0.5, 'Average Loan Amount')

# %%
# 2.How does the credit score vary with the annual income?
plt.figure(figsize=(8,6))
sns.scatterplot(data = df,x='Credit Score', y = 'Annual Income')
plt.title('Credit Score vs Annual Income')
plt.show()

# %%
 3.Is there a correlation between the number of open accounts and the current credit balance?
Correlation_numofopenaccount_numofcreditbalance = df['Number of Open Accounts'].corr(df['Current Credit Balance'])
print(f'correlation between the number of open accounts and the current credit balance: {Correlation_numofopenaccount_numofcreditbalance:.2f}')
# Out:
# Object `balance` not found.
# correlation between the number of open accounts and the current credit balance: 0.23

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 7.Is there a correlation between years of credit history and the current credit balance?
Correlation_CreditHistoty_CurrentCreditBalance= df['Years of Credit History'].corr(df['Current Credit Balance'])
print(f'Correlation between years of credit history and the current credit balance: {Correlation_CreditHistoty_CurrentCreditBalance: .2f}')
# Out:
# Correlation between years of credit history and the current credit balance:  0.21

# %%
# 11.Is there a correlation between the current loan amount and the number of open accounts?
Correlation_LoanAmount_OpenAccounts = df['Current Loan Amount'].corr(df['Number of Open Accounts'])
print(f'Correlation between the current loan amount and the number of open accounts: {Correlation_LoanAmount_OpenAccounts: .2f}')
# Out:
# Correlation between the current loan amount and the number of open accounts:  0.00

# %%
# 4.What is the distribution of credit scores across different home ownership types?
plt.figure(figsize=(6,4))
sns.boxplot(data=df,x='Credit Score' , y= 'Home Ownership')
plt.title('Distribution of credit scores across different home ownership')
plt.show()

# %%
# 6.What is the average monthly debt for each term (short-term vs. long-term)?
Average_monthly_debt = df.groupby('Term')['Monthly Debt'].mean()
plt.figure(figsize=(6,4))
sns.barplot(x=Average_monthly_debt.index,y=Average_monthly_debt.values)
plt.title('Average monthly debt')
plt.ylabel('Average Monthly Debt')
plt.show()

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 8.How does the credit score vary with the years in the current job?
plt.figure(figsize=(6,4))
sns.boxplot(data=df,x='Credit Score',y='Years in current job')
plt.title('Credit score vary with the years in the current job')
plt.show()

# %%
# 9.What is the relationship between the number of credit problems and the number of open accounts?
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x='Number of Credit Problems',y='Number of Open Accounts')
plt.title('Relationship between Credit Problems & Open Accounts')
plt.show()

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 10.What is the distribution of annual income across different loan statuses?
plt.figure(figsize=(6,4))
sns.boxplot(data=df,x='Annual Income',y='Loan Status')
plt.title('Annual Income vs Loan Status')
plt.show()

# %%
# 12.How does the monthly debt vary with the years of credit history?
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,y='Monthly Debt',x='Years of Credit History')
plt.title('Monthly debt vs Credit history')
plt.show()

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 13.What is the average annual income for each purpose of loan?
Average_annualloan_Eachpurposeloan=df.groupby('Purpose')['Annual Income'].mean()
plt.figure(figsize=(10,4))
sns.barplot(x=Average_annualloan_Eachpurposeloan.index,y=Average_annualloan_Eachpurposeloan.values)
plt.title('Average Annual Income For Each Purpose of Loan')
plt.xticks(rotation=45)
plt.xlabel('Purpose')
plt.ylabel('Annual Income')
plt.show()

# %%
# 14.How does the credit score vary with the number of credit problems?
plt.figure(figsize=(8,4))
sns.scatterplot(data=df,y='Credit Score',x='Number of Credit Problems')
plt.title('Credit Score vs Number of Credit Problems')
plt.xlabel('Credit Score')
plt.ylabel('Number of Credit Problems')
plt.show()

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 15.Is there a correlation between the number of credit problems and the current credit balance?
Correlation_creditproblem_creditbalance=df['Number of Credit Problems'].corr(df['Current Credit Balance'])
print(f'correlation between the number of credit problems and the current credit balance: {Correlation_creditproblem_creditbalance: .2f}')
# Out:
# correlation between the number of credit problems and the current credit balance: -0.11

# %%
# 16.What is the distribution of current loan amounts across different home ownership types?
plt.figure(figsize=(8,4))
sns.boxplot(data=df,x='Current Loan Amount',y='Home Ownership')
plt.title('Distribution of current loan amounts across different home ownership types')
plt.xlabel('Current Loan Amount')
plt.ylabel('Home Ownership')
plt.xticks(rotation=45)
plt.show()

# %%
# 17.How does the annual income vary with the years in the current job?
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Years in current job',y='Annual Income')
plt.title('Annual Income Vs Years in current job')
plt.ylabel('Annual Income')
plt.xlabel('Years in current job')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 18.Is there a correlation between the current loan amount and the monthly debt?
Correlation_loanamount_Monthlydebt=df['Current Loan Amount'].corr(df['Monthly Debt'])
print(f'Correlation between the current loan amount and the monthly debt: {Correlation_loanamount_Monthlydebt: .2f}')
# Out:
# Correlation between the current loan amount and the monthly debt: -0.01

# %%
# 19.What is the average monthly debt for each home ownership type?
Average_Monthly_debt=df.groupby('Home Ownership')['Monthly Debt'].mean()
plt.figure(figsize=(6,4))
sns.barplot(x=Average_Monthly_debt.index,y=Average_Monthly_debt.values)
plt.title('Average monthly debt')
plt.xlabel('Home Ownership')
plt.ylabel('Monthly Debt')
plt.show()

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 20.How does the credit score vary with the number of open accounts?
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,y='Credit Score',x='Number of Open Accounts')
plt.title('Credit Score vs Number of Open Accounts')
plt.xlabel('Number of Open Accounts')
plt.ylabel('Credit Score',)
plt.show()

# %%
# 21.What is the distribution of credit scores across different loan statuses?
plt.figure(figsize=(6,4))
sns.boxplot(data=df,y='Credit Score',x='Loan Status')
plt.title('Distribution of credit scores & Loan status')
plt.xlabel('Loan Status')
plt.ylabel('Credit Score')
plt.show()

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 22.Is there a correlation between the current loan amount and the years of credit history?
Correlation_Loanamount_credithistory=df['Current Loan Amount'].corr(df['Years of Credit History'])
print(f'Correlation between the current loan amount and the years of credit history: {Correlation_Loanamount_credithistory : .2f}')
# Out:
# Correlation between the current loan amount and the years of credit history:  0.02

# %%
# 23.How does the monthly debt vary with the number of credit problems?
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,y='Monthly Debt',x='Number of Credit Problems')
plt.title('Monthly debt vs number of credit problems')
plt.ylabel='Monthly Debt'
plt.xlabel='Number of Credit Problems'
plt.show()

# %%
# 24.What is the average current loan amount for each purpose of loan?
plt.figure(figsize=(10,4))
Average_curentloan_amount= df.groupby('Purpose')['Current Loan Amount'].mean()
sns.barplot(x=Average_curentloan_amount.index,y=Average_curentloan_amount.values)
plt.title('Average Current Loan Amount For Purpose')
plt.xticks(rotation=45)
plt.xlabel('Purpose')
plt.ylabel('Average Loan Amount')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[232], line 7
#       5 plt.title('Average Current Loan Amount For Purpose')
#       6 plt.xticks(rotation=45)
# ----> 7 plt.xlabel('Purpose')
#       8 plt.ylabel('Average Loan Amount')
#       9 plt.show()
#
# TypeError: 'str' object is not callable

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 25.How does the credit score vary with the current credit balance?
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,y='Credit Score',x='Current Credit Balance')
plt.title('Credit score vs Current credit balance')
plt.xlabel('Current Credit Balance')
plt.ylabel('Credit Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[238], line 5
#       3 sns.scatterplot(data=df,y='Credit Score',x='Current Credit Balance')
#       4 plt.title('Credit score vs Current credit balance')
# ----> 5 plt.xlabel('Current Credit Balance')
#       6 plt.ylabel('Credit Score')
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %%
# 26.Is there a correlation between the annual income and the current credit balance?
Correlation_annualincome_CreditBalance=df['Annual Income'].corr(df['Current Credit Balance'])
print(f'Correlation between the annual income and the current credit balance: {Correlation_annualincome_CreditBalance: .2f}')
# Out:
# Correlation between the annual income and the current credit balance:  0.31

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 27.What is the distribution of annual income across different terms (short-term vs. long-term)?
plt.figure(figsize=(6,4))
sns.boxplot(data=df,y='Annual Income',x='Term')
plt.title('Annual income vs terms')
plt.xlabel('Term')
plt.ylabel('Annual Income')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[248], line 5
#       3 sns.boxplot(data=df,y='Annual Income',x='Term')
#       4 plt.title('Annual income vs terms')
# ----> 5 plt.xlabel('Term')
#       6 plt.ylabel('Annual Income')
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %%
# 28.How does the credit score vary with the number of credit problems?
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,y='Credit Score',x='Number of Credit Problems')
plt.title('Credit score vs Number of credit problems')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Credit Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[254], line 5
#       3 sns.scatterplot(data=df,y='Credit Score',x='Number of Credit Problems')
#       4 plt.title('Credit score vs Number of credit problems')
# ----> 5 plt.xlabel('Number of Credit Problems')
#       6 plt.ylabel('Credit Score')
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 29.Is there a correlation between the current loan amount and the number of credit problems?
Correlation_Currentloan_CreditProblem=df['Current Loan Amount'].corr(df['Number of Credit Problems'])
print(f'Correlation between the current loan amount and the number of credit problems: {Correlation_Currentloan_CreditProblem : .2f}')
# Out:
# Correlation between the current loan amount and the number of credit problems: -0.00

# %%
# 30.What is the relationship between the number of open accounts and the years of credit history?
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,y='Number of Open Accounts',x='Years of Credit History')
plt.title('Number of open accounts vs years of credit history')
plt.xlabel('Years of Credit History')
plt.xlabel('Number of Open Accounts')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[262], line 5
#       3 sns.scatterplot(data=df,y='Number of Open Accounts',x='Years of Credit History')
#       4 plt.title('Number of open accounts vs years of credit history')
# ----> 5 plt.xlabel('Years of Credit History')
#       6 plt.xlabel('Number of Open Accounts')
#       7 plt.show()
#
# TypeError: 'str' object is not callable
